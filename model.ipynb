# %%
import pandas as pd

# %%
statistics = pd.read_csv("mistplay-challenge/user_apps_statistics.csv")
purchases = pd.read_csv("mistplay-challenge/user_purchase_events.csv")
users = pd.read_csv("mistplay-challenge/user_table.csv")

# %%
users.describe()
# Out:
#           Unnamed: 0  installed_Mistplay        gender           ref  \
# count   99740.000000        9.974000e+04  99616.000000  99740.000000
# mean    55842.419601        1.562629e+12      0.463018      0.049469
# std     32230.867130        7.236000e+09      0.522060      0.216845
# min         0.000000        1.511779e+12      0.000000      0.000000
# 25%     27933.750000        1.560833e+12      0.000000      0.000000
# 50%     55832.500000        1.563849e+12      0.000000      0.000000
# 75%     83760.250000        1.566753e+12      1.000000      0.000000
# max    111663.000000        1.572072e+12      2.000000      1.000000
#
#        installed_Mistplay_timezone  game_install_timezone
# count                 9.974000e+04           9.824000e+04
# mean                 -9.124767e+06          -9.115789e+06
# std                   1.884723e+07           1.885214e+07
# min                  -3.960000e+07          -3.960000e+07
# ...
